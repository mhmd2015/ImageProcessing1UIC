# %% [markdown]
# <a href="https://colab.research.google.com/github/mhmd2015/ImageProcessing1UIC/blob/main/DIP_Canny_Filter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Read the image
image = cv2.imread('20220723_125312.jpg')

# Convert the image to grayscale
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)


# Apply Canny edge detector
edges = cv2.Canny(gray_image, 50, 150)  # 50 and 150 are the minVal and maxVal thresholds

# Save the edge-detected image (optional)
cv2.imwrite('edges.jpg', edges)

# Display the edge-detected image
plt.figure(figsize=(24, 16))

plt.subplot(1, 3, 1)
plt.imshow(edges, cmap='gray')
