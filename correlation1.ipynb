# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
def convolution_2d(image, filt):
    m, n = filt.shape
    if(m == n):
        y, x = image.shape
        y = y - m +1
        x = x - m +1
        new_image = np.zeros((x,y))
        for i in range(y):
            for j in range(x):
                new_image[i][j]=np.sum(image[i:i+m, j:j+m] * filt)
        return new_image
    
def correlation_2d(image, filt):
    m, n = filt.shape
    y, x = image.shape
    y = y - m + 1
    x = x - m + 1
    new_image = np.zeros((y,x))
    for i in range(y):
        for j in range(x):
            new_image[i][j] = np.sum(image[i:i+m, j:j+m] * filt)
    return new_image

# %%
#imgPath = 'image1.jpeg'
#image = mpimg.imread(imgPath)[ :, :, 0] #if image RGB just take one channel


imgPath = 'noise.jpeg'
image = mpimg.imread(imgPath) #if image RGB just take one channel


#filt = np.array([[1/9,1/9,1/9],[1/9,1/9,1/9],[1/9,1/9,1/9]])
filt = np.array([[3/9,1/9,1/9],[4/9,8/9,1/9],[5/9,7/9,1/9]])
#filt = np.array([[1/9,1/9,1/9],[1/9,1/9,1/9],[1/9,1/9,1/9]])

# %%
image
# Out:
# array([[ 14,  29,  22, ...,  20,  63,  70],
#        [  8,  16,   0, ...,  59,  88,  75],
#        [ 39,   4,  40, ...,  79,  91,  63],
#        ...,
#        [ 59,  46,  51, ...,  26, 253,  52],
#        [ 39,   2,  35, ...,  39,  30,  32],
#        [  0,  50,  53, ...,  26,  41,  32]], dtype=uint8)

# %%
flipped_filt = np.flip(np.flip(filt, 0), 1)

result = correlation_2d(image, flipped_filt)


fig, axarr = plt.subplots(1,2)

axarr[0].imshow(image,cmap='gray')
axarr[0].set_title('Original Image')


axarr[1].imshow(result,cmap='gray')
axarr[1].set_title('Convolved Image')
# Out:
# Text(0.5, 1.0, 'Convolved Image')

# %%
"""
filters=[
np.array([[1/9,1/9,1/9],[1/9,1/9,1/9],[1/9,1/9,1/9]]),
np.array([[3/9,1/9,1/9],[4/9,8/9,1/9],[5/9,7/9,1/9]]),
np.array([[1,1,0],[1,0,1],[0,1,1]]),
np.array([[1,1,1],[1,1,1],[1,1,1]]),
np.array([[0,1/9,0],[0,1/9,0],[0,1/9,0]])
]
"""

filters=[
np.array([[1/9,1/9,1/9],[1/9,1/9,1/9],[1/9,1/9,1/9]]),
np.array([[0,1/9,0],[0,1/9,0],[0,1/9,0]]),
np.array([[1/9,0,0],[1/9,0,0],[1/9,0,0]]),
np.array([[1/9,1/9,1/9],[0,0,0],[0,0,0]]),
np.array([[1/9,0,0],[0,1/9,0],[0,0,1/9]]),
]

"""
filters=[
    np.array([[1/4,1/4,0],[1/4,1/4,0],[0,0,0]])
]
"""



plt.imshow(image,cmap='gray')
plt.title('Original Image')
plt.axis('off')
plt.show()

for f in range(len(filters)):
    flipped_filt = np.flip(np.flip(filters[f], 0), 1)

    result = correlation_2d(image, flipped_filt)
    
    plt.imshow(result,cmap='gray')
    plt.title(flipped_filt)
    plt.axis('off')
    plt.show()

# %%
"""
filters=[
np.array([[1/9,1/9,1/9],[1/9,1/9,1/9],[1/9,1/9,1/9]]),
np.array([[0,1/9,0],[0,1/9,0],[0,1/9,0]]),
np.array([[1/9,0,0],[1/9,0,0],[1/9,0,0]]),
np.array([[1/9,1/9,1/9],[0,0,0],[0,0,0]]),
np.array([[1/9,0,0],[0,1/9,0],[0,0,1/9]]),
]
"""
filters=[

np.array([[1/4,1/4,0],[1/4,1,4,0],[0,0,0]])
]


plt.imshow(image,cmap='gray')
plt.title('Original Image')
plt.axis('off')
plt.show()

for f in range(len(filters)):

    fig, axarr = plt.subplots(1,2)

    result = convolution_2d(image,filters[f])
    axarr[0].imshow(result,cmap='gray')
    axarr[0].set_title(filters[f])
    

    flipped_filt = np.flip(np.flip(filters[f], 0), 1)

    correlate = correlation_2d(image, flipped_filt)

    axarr[1].imshow(correlate,cmap='gray')
    axarr[1].set_title(flipped_filt)
    

    plt.show()
# Out:
# C:\Users\myahya\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\ipykernel_launcher.py:12: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   if sys.path[0] == "":
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_31060\4156326045.py in <module>
#      23     fig, axarr = plt.subplots(1,2)
#      24
# ---> 25     result = convolution_2d(image,filters[f])
#      26     axarr[0].imshow(result,cmap='gray')
#      27     axarr[0].set_title(filters[f])
#
# ~\AppData\Local\Temp\ipykernel_31060\1319082797.py in convolution_2d(image, filt)
#       1 def convolution_2d(image, filt):
# ----> 2     m, n = filt.shape
#       3     if(m == n):
#       4         y, x = image.shape
#       5         y = y - m +1
#
# ValueError: not enough values to unpack (expected 2, got 1)

# %%
filter = np.array([[1/4,1/4,0],[1/4,1/4,0],[0,0,0]])



plt.imshow(image,cmap='gray')
plt.title('Original Image')
plt.axis('off')
plt.show()





result = convolution_2d(image,filter)
plt.imshow(result,cmap='gray')
plt.title(filter)
plt.show()

flipped_filt = np.flip(np.flip(filter, 0), 1)

correlate = correlation_2d(image, flipped_filt)

plt.imshow(correlate,cmap='gray')
plt.title(flipped_filt)


plt.show()
