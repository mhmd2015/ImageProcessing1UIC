# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
def convolution_2d(image, filt):
    m, n = filt.shape
    if(m == n):
        y, x = image.shape
        y = y - m +1
        x = x - m +1
        new_image = np.zeros((x,y))
        for i in range(y):
            for j in range(x):
                new_image[i][j]=np.sum(image[i:i+m, j:j+m] * filt)
        return new_image

# %%
#imgPath = 'image1.jpeg'
#image = mpimg.imread(imgPath)[ :, :, 0] #if image RGB just take one channel


imgPath = 'noise.jpeg'
image = mpimg.imread(imgPath) #if image RGB just take one channel


#filt = np.array([[1/9,1/9,1/9],[1/9,1/9,1/9],[1/9,1/9,1/9]])
filt = np.array([[3/9,1/9,1/9],[4/9,8/9,1/9],[5/9,7/9,1/9]])
#filt = np.array([[1/9,1/9,1/9],[1/9,1/9,1/9],[1/9,1/9,1/9]])

# %%
image
# Out:
# array([[ 14,  29,  22, ...,  20,  63,  70],
#        [  8,  16,   0, ...,  59,  88,  75],
#        [ 39,   4,  40, ...,  79,  91,  63],
#        ...,
#        [ 59,  46,  51, ...,  26, 253,  52],
#        [ 39,   2,  35, ...,  39,  30,  32],
#        [  0,  50,  53, ...,  26,  41,  32]], dtype=uint8)

# %%
result = convolution_2d(image,filt)

fig, axarr = plt.subplots(1,2)

axarr[0].imshow(image,cmap='gray')
axarr[0].set_title('Original Image')


axarr[1].imshow(result,cmap='gray')
axarr[1].set_title('Convolved Image')
# Out:
# Text(0.5, 1.0, 'Convolved Image')

# %%
filt1 = np.array([[1/9,1/9,1/9],[1/9,1/9,1/9],[1/9,1/9,1/9]])
filt2 = np.array([[3/9,1/9,1/9],[4/9,8/9,1/9],[5/9,7/9,1/9]])
filt3 = np.array([[3/9,1/9,0],[4/9,0,1/9],[0,7/9,1/9]])



fig, axarr = plt.subplots(1,4)

axarr[0].imshow(image,cmap='gray')
axarr[0].set_title('Original Image')

result1 = convolution_2d(image,filt1)
axarr[1].imshow(result1,cmap='gray')
axarr[1].set_title('Convolved Image')

result2 = convolution_2d(image,filt2)
axarr[2].imshow(result2,cmap='gray')
axarr[2].set_title('Convolved Image')

result3 = convolution_2d(image,filt3)
axarr[3].imshow(result3,cmap='gray')
axarr[3].set_title('Convolved Image')

plt.show()

# %%
"""
filters=[
np.array([[1/9,1/9,1/9],[1/9,1/9,1/9],[1/9,1/9,1/9]]),
np.array([[3/9,1/9,1/9],[4/9,8/9,1/9],[5/9,7/9,1/9]]),
np.array([[1,1,0],[1,0,1],[0,1,1]]),
np.array([[1,1,1],[1,1,1],[1,1,1]]),
np.array([[0,1/9,0],[0,1/9,0],[0,1/9,0]])
]
"""
"""
filters=[
np.array([[1/9,1/9,1/9],[1/9,1/9,1/9],[1/9,1/9,1/9]]),
np.array([[0,1/9,0],[0,1/9,0],[0,1/9,0]]),
np.array([[1/9,0,0],[1/9,0,0],[1/9,0,0]]),
np.array([[1/9,1/9,1/9],[0,0,0],[0,0,0]])
]
"""

filters=[

np.array([[1/4,1/4,0],[1/4,1/4,0],[0,0,0]])

]




plt.imshow(image,cmap='gray')
plt.title('Original Image')
plt.axis('off')
plt.show()

for f in range(len(filters)):
    result = convolution_2d(image,filters[f])
    plt.imshow(result,cmap='gray')
    plt.title(filters[f])
    plt.axis('off')
    plt.show()

# %%
def median_filter_2d(image, filt_size):
    m, n = filt_size, filt_size  # assuming the filter is square
    y, x = image.shape
    y = y - m + 1
    x = x - m + 1
    new_image = np.zeros((y, x))
    for i in range(y):
        for j in range(x):
            new_image[i][j] = np.median(image[i:i+m, j:j+m])
    return new_image

# %%
# Display the original and median-filtered images
plt.imshow(image, cmap='gray')
plt.title('Original Image')
plt.axis('off')
plt.show()

# Apply the median filter
filter_size = 2
result_median = median_filter_2d(image, filter_size)
plt.imshow(result_median, cmap='gray')
plt.title('Median Filtered Image with 2')
plt.axis('off')
plt.show()

# Apply the median filter
filter_size = 3
result_median = median_filter_2d(image, filter_size)
plt.imshow(result_median, cmap='gray')
plt.title('Median Filtered Image with 3')
plt.axis('off')
plt.show()

# Apply the median filter
filter_size = 4
result_median = median_filter_2d(image, filter_size)
plt.imshow(result_median, cmap='gray')
plt.title('Median Filtered Image with 4')
plt.axis('off')
plt.show()

# Apply the median filter
filter_size = 32
result_median = median_filter_2d(image, filter_size)
plt.imshow(result_median, cmap='gray')
plt.title('Median Filtered Image with 32')
plt.axis('off')
plt.show()
